# %% [markdown]
# # Trexquant Interview Project (The Hangman Game)
#
# * Copyright Trexquant Investment LP. All Rights Reserved.
# * Redistribution of this question without written consent from Trexquant is prohibited

# %% [markdown]
# ## Instruction:
# For this coding test, your mission is to write an algorithm that plays the game of Hangman through our API server.
#
# When a user plays Hangman, the server first selects a secret word at random from a list. The server then returns a row of underscores (space separated)—one for each letter in the secret word—and asks the user to guess a letter. If the user guesses a letter that is in the word, the word is redisplayed with all instances of that letter shown in the correct positions, along with any letters correctly guessed on previous turns. If the letter does not appear in the word, the user is charged with an incorrect guess. The user keeps guessing letters until either (1) the user has correctly guessed all the letters in the word
# or (2) the user has made six incorrect guesses.
#
# You are required to write a "guess" function that takes current word (with underscores) as input and returns a guess letter. You will use the API codes below to play 1,000 Hangman games. You have the opportunity to practice before you want to start recording your game results.
#
# Your algorithm is permitted to use a training set of approximately 250,000 dictionary words. Your algorithm will be tested on an entirely disjoint set of 250,000 dictionary words. Please note that this means the words that you will ultimately be tested on do NOT appear in the dictionary that you are given. You are not permitted to use any dictionary other than the training dictionary we provided. This requirement will be strictly enforced by code review.
#
# You are provided with a basic, working algorithm. This algorithm will match the provided masked string (e.g. a _ _ l e) to all possible words in the dictionary, tabulate the frequency of letters appearing in these possible words, and then guess the letter with the highest frequency of appearence that has not already been guessed. If there are no remaining words that match then it will default back to the character frequency distribution of the entire dictionary.
#
# This benchmark strategy is successful approximately 18% of the time. Your task is to design an algorithm that significantly outperforms this benchmark.

# %%
import xgboost as xgb
import numpy as np
import pandas as pd
import pickle
import string

class HangmanXGBoostPredictor:
    def __init__(self, model_path="xgboost_hangman_models2.pkl", pos_features=65):
        self.alphabet = list(string.ascii_lowercase)
        self.num_classes = len(self.alphabet)
        self.models = []
        self.pos_features = pos_features
        self._load_models(model_path)

    def _load_models(self, model_path):
        with open(model_path, 'rb') as f:
            self.models = pickle.load(f)

    def _encode_word_state(self, word: str, guessed_letters: set) -> np.ndarray:
        feat = np.full(self.pos_features, -1, dtype=np.int8)
        length = len(word)
        offset = self.pos_features - length

        for i, ch in enumerate(word):
            code = 0 if ch == '*' else ord(ch) - ord('a') + 1
            feat[i] = code
            feat[offset + i] = code

        return feat.reshape(1, -1)

    def predict_letter(self, word: str, guessed_letters: set) -> str:
        features = self._encode_word_state(word, guessed_letters)
        scores = []
        # print(self.models)
        for idx, model in enumerate(self.models.items()):
            # print(idx,model)
            model=model[1]
            letter = self.alphabet[idx]
            if letter in guessed_letters:
                scores.append(-np.inf)
                continue
            prob = model.predict_proba(features)[0][1]  # probability of presence
            scores.append(prob)

        return scores

# %%
import torch
from transformers import CanineTokenizer, CanineConfig, CanineForSequenceClassification
from transformers import CanineConfig, CanineTokenizer, AutoModelForSequenceClassification
from scipy.special import softmax

# # Constants for separating and masking in the CANINE input sequence
# CANINE_SEP_TOKEN   = " [SEP] "
# CANINE_MASK_TOKEN  = "[MASK]"

class CanineHangmanPlayer:
    def __init__(self, pretrained_model_path: str = "google/canine-s", device: torch.device = None,xgb=None):
        # Load CANINE tokenizer & config
        self.tokenizer = CanineTokenizer.from_pretrained('google/canine-s')
        self.config    = CanineConfig.from_pretrained(pretrained_model_path)
        self.config.num_labels = 26
        self.xgb=xgb
        self.nice=1
        self.trigger=1
        self.all_letters = [chr(i) for i in range(ord('a'), ord('z')+1)]
        self.state=False
        self.guesses={}

        
        # Set up device
        self.device = "cuda"#device or torch.device("cuda" if torch.cuda.is_available() else "cpu")
        
        # Load a sequence-classification head on top of CANINE
        self.model =AutoModelForSequenceClassification.from_pretrained(
            pretrained_model_path,
            config=self.config).to(self.device)
        
        # Tokens for building the game state string
        self.CANINE_MASK_TOKEN = self.tokenizer.mask_token
        self.CANINE_SEP_TOKEN = self.tokenizer.sep_token
        
        # Toggle for self-play finetuning
        self.training = False
        
    def predict(self,word,guesses):
            encoded_word=word.replace(" ","").replace("_","*")
            missing_count = encoded_word.count("*")

            guesses={x:True for x in guesses}
                

            # check = self.xgb.predict_letter(''.join(encoded_word), guesses)
            state = ''.join(guesses.keys()) + self.CANINE_SEP_TOKEN + encoded_word.replace('*', self.CANINE_MASK_TOKEN)
            enc = self.tokenizer(state, padding="max_length", truncation=True, max_length=64, return_tensors="pt").to(self.device)

            with torch.no_grad():
                logits = self.model(**enc).logits

            # arr = logits.cpu().numpy()[0]
            arr = softmax(logits.cpu().numpy()[0]).tolist()
            # arr1=softmax(np.argsort(arr)[::-1]).tolist()
            # arr1=softmax(arr1)
            
            total = sum(arr)
            
            guess_idx = np.argmax(arr)
            # arr = [x / total for x in arr]
            
            # arr1=np.argsort(check)[::-1].tolist()
            # rank1=np.argsort(check)[::-1].tolist()
            # pos1=rank1.index(guess_idx)
            # guess = all_letters[guess_idx]
            # org=arr[guess_idx]
            # verify=check[guess_idx]
            return self.all_letters[guess_idx],arr[guess_idx]


            if org<0.005 and pos1>=7 and missing_count<=3:
                # print("Trigger")
                trigger=True
                guess_idx = rank1[0]
            guess = self.all_letters[guess_idx]
            # guesses[guess]=True
            return guess

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pickle
import re
from collections import Counter

def build_dictionary(dictionary_file_location):
    text_file = open(dictionary_file_location,"r")
    full_dictionary = text_file.read().splitlines()
    text_file.close()
    return full_dictionary

words = build_dictionary("words_250000_train.txt")
value = {ch: i for i, ch in {i: chr(96 + i) for i in range(1, 27)}.items()}
value["_"] = 0
value_rev = {i: chr(96 + i) for i in range(1, 27)}
value_rev[0] = "_"
# value_rev[27] = "_"

# %%
import re
from collections import Counter
import numpy as np


def guesss(pattern, tried, verbose=False):
    """
    Predict next letter: use model.predict or fallback to substrings analysis.
    Returns (letter, use_model_flag).
    """
    clean = pattern.replace(" ", "")
    letter, prob = model.predict(clean, tried)
    prob *= 1.2

    for size in range(8, 2, -1):
        allow_multi = size > 3
        candidate, cand_prob = create_substrings(clean, tried_letters=tried,
                                                window=size, min_prob=prob,
                                                allow_multiple=allow_multi)
        if candidate:
            if verbose:
                print(f"used{size}", candidate, cand_prob)
            return candidate, False

    return letter, True


def create_substrings(pattern_str, tried_letters=None, window=6, min_prob=0.1, allow_multiple=False):
    tried_letters = tried_letters or []
    clean = pattern_str.replace(" ", "")

    fragments = []
    for idx, ch in enumerate(clean):
        if ch == '_':
            left = max(idx - (window - 1), 0)
            right = min(idx + window, len(clean))
            placeholder = '.'
            segment = clean[left:idx] + placeholder + clean[idx+1:right]
            if allow_multiple or _is_isolated(clean, idx):
                fragments.append(segment.replace('_', '*') if allow_multiple else segment)

    subs = [seg[i:i+window] for seg in fragments for i in range(len(seg) - window + 1)]
    if allow_multiple:
        subs = [s for s in subs if s.count('*') < 2]
    else:
        subs = [s for s in subs if '_' not in s]
    subs = [s for s in subs if len(s) == window]

    if not subs:
        return None, None

    distributions = []
    for s in subs:
        dot_pos = s.index('.')
        pattern = s.replace('*', '.') if allow_multiple else s
        counts = _count_matching_letters(pattern, dot_pos, tried_letters)
        if counts:
            total = sum(counts.values())
            distributions.append({ltr: cnt/total for ltr, cnt in counts.items()})

    if not distributions:
        return None, None

    agg = _aggregate_probs(distributions)
    best_letter, best_prob = max(agg.items(), key=lambda x: x[1])
    if best_prob < min_prob:
        return None, None
    return best_letter, best_prob


def _is_isolated(s, i):
    return (i == 0 or s[i-1] != '_') and (i == len(s)-1 or s[i+1] != '_')


def _count_matching_letters(regex, dot_index, tried):
    counts = Counter()
    for w in words:
        m = re.search(regex, w)
        if m:
            letter = w[m.start() + dot_index]
            if letter not in tried:
                counts[letter] += 1
    return counts


def _aggregate_probs(dist_list):
    alpha_counts = np.zeros(26)
    for dist in dist_list:
        for ltr, p in dist.items():
            alpha_counts[value[ltr]-1] += p
    alpha_probs = alpha_counts / alpha_counts.sum()
    return {value_rev[i+1]: prob for i, prob in enumerate(alpha_probs)}

# %%
xgb = HangmanXGBoostPredictor("xgboost_hangman_models2.pkl")
model=CanineHangmanPlayer("canine-pretrained-hangman-checkpoints/canine-pretrained-hangman-checkpoint-7",xgb=xgb)
model.training=False
# Out:
# tokenizer_config.json:   0%|          | 0.00/854 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/657 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/670 [00:00<?, ?B/s]

# %%
import json
import requests
import random
import string
import secrets
import time
import re
import collections

try:
    from urllib.parse import parse_qs, urlencode, urlparse
except ImportError:
    from urlparse import parse_qs, urlparse
    from urllib import urlencode

    
from requests.packages.urllib3.exceptions import InsecureRequestWarning

requests.packages.urllib3.disable_warnings(InsecureRequestWarning)

# %%
class HangmanAPI(object):
    def __init__(self, access_token=None, session=None, timeout=None):
        self.hangman_url = self.determine_hangman_url()
        self.access_token = access_token
        self.session = session or requests.Session()
        self.timeout = timeout
        self.guessed_letters = []
        
        full_dictionary_location = "words_250000_train.txt"
        self.full_dictionary = self.build_dictionary(full_dictionary_location)        
        self.full_dictionary_common_letter_sorted = collections.Counter("".join(self.full_dictionary)).most_common()
        
        self.current_dictionary = []
        
    @staticmethod
    def determine_hangman_url():
        links = ['https://trexsim.com']

        data = {link: 0 for link in links}

        for link in links:

            requests.get(link)

            for i in range(10):
                s = time.time()
                requests.get(link)
                data[link] = time.time() - s

        link = sorted(data.items(), key=lambda x: x[1])[0][0]
        link += '/trexsim/hangman'
        return link

    def guess(self, word): # word input example: "_ p p _ e "
        ###############################################
        # Replace with your own "guess" function here #
        ###############################################
        ans,a=guesss(word,self.guessed_letters)
        return ans
 
    def build_dictionary(self, dictionary_file_location):
        text_file = open(dictionary_file_location,"r")
        full_dictionary = text_file.read().splitlines()
        text_file.close()
        return full_dictionary
                
    def start_game(self, practice=True, verbose=True):
        # reset guessed letters to empty set and current plausible dictionary to the full dictionary
        self.guessed_letters = []
        self.current_dictionary = self.full_dictionary
                         
        response = self.request("/new_game", {"practice":practice})
        if response.get('status')=="approved":
            game_id = response.get('game_id')
            word = response.get('word')
            tries_remains = response.get('tries_remains')
            if verbose:
                print("Successfully start a new game! Game ID: {0}. # of tries remaining: {1}. Word: {2}.".format(game_id, tries_remains, word))
            while tries_remains>0:
                # get guessed letter from user code
                guess_letter = self.guess(word)
                    
                # append guessed letter to guessed letters field in hangman object
                self.guessed_letters.append(guess_letter)
                if verbose:
                    print("Guessing letter: {0}".format(guess_letter))
                    
                try:    
                    res = self.request("/guess_letter", {"request":"guess_letter", "game_id":game_id, "letter":guess_letter})
                except HangmanAPIError:
                    print('HangmanAPIError exception caught on request.')
                    continue
                except Exception as e:
                    print('Other exception caught on request.')
                    raise e
               
                if verbose:
                    print("Sever response: {0}".format(res))
                status = res.get('status')
                tries_remains = res.get('tries_remains')
                if status=="success":
                    if verbose:
                        print("Successfully finished game: {0}".format(game_id))
                    return True
                elif status=="failed":
                    reason = res.get('reason', '# of tries exceeded!')
                    if verbose:
                        print("Failed game: {0}. Because of: {1}".format(game_id, reason))
                    return False
                elif status=="ongoing":
                    word = res.get('word')
        else:
            if verbose:
                print("Failed to start a new game")
        return status=="success"
        
    def my_status(self):
        return self.request("/my_status", {})
    
    def request(
            self, path, args=None, post_args=None, method=None):
        if args is None:
            args = dict()
        if post_args is not None:
            method = "POST"

        # Add `access_token` to post_args or args if it has not already been
        # included.
        if self.access_token:
            # If post_args exists, we assume that args either does not exists
            # or it does not need `access_token`.
            if post_args and "access_token" not in post_args:
                post_args["access_token"] = self.access_token
            elif "access_token" not in args:
                args["access_token"] = self.access_token

        time.sleep(0.2)

        num_retry, time_sleep = 50, 2
        for it in range(num_retry):
            try:
                response = self.session.request(
                    method or "GET",
                    self.hangman_url + path,
                    timeout=self.timeout,
                    params=args,
                    data=post_args,
                    verify=False
                )
                break
            except requests.HTTPError as e:
                response = json.loads(e.read())
                raise HangmanAPIError(response)
            except requests.exceptions.SSLError as e:
                if it + 1 == num_retry:
                    raise
                time.sleep(time_sleep)

        headers = response.headers
        if 'json' in headers['content-type']:
            result = response.json()
        elif "access_token" in parse_qs(response.text):
            query_str = parse_qs(response.text)
            if "access_token" in query_str:
                result = {"access_token": query_str["access_token"][0]}
                if "expires" in query_str:
                    result["expires"] = query_str["expires"][0]
            else:
                raise HangmanAPIError(response.json())
        else:
            raise HangmanAPIError('Maintype was not text, or querystring')

        if result and isinstance(result, dict) and result.get("error"):
            raise HangmanAPIError(result)
        return result
    
class HangmanAPIError(Exception):
    def __init__(self, result):
        self.result = result
        self.code = None
        try:
            self.type = result["error_code"]
        except (KeyError, TypeError):
            self.type = ""

        try:
            self.message = result["error_description"]
        except (KeyError, TypeError):
            try:
                self.message = result["error"]["message"]
                self.code = result["error"].get("code")
                if not self.type:
                    self.type = result["error"].get("type", "")
            except (KeyError, TypeError):
                try:
                    self.message = result["error_msg"]
                except (KeyError, TypeError):
                    self.message = result

        Exception.__init__(self, self.message)

# %% [markdown]
# # API Usage Examples

# %% [markdown]
# ## To start a new game:
# 1. Make sure you have implemented your own "guess" method.
# 2. Use the access_token that we sent you to create your HangmanAPI object.
# 3. Start a game by calling "start_game" method.
# 4. If you wish to test your function without being recorded, set "practice" parameter to 1.
# 5. Note: You have a rate limit of 20 new games per minute. DO NOT start more than 20 new games within one minute.

# %%
api = HangmanAPI(access_token="e67b107337bbe4cc1c633dd23d2a03", timeout=2000)

# %% [markdown]
# ## Playing practice games:
# You can use the command below to play up to 100,000 practice games.

# %%
api.start_game(practice=1,verbose=True)
[total_practice_runs,total_recorded_runs,total_recorded_successes,total_practice_successes] = api.my_status() # Get my game stats: (# of tries, # of wins)
practice_success_rate = total_practice_successes / total_practice_runs

print('run %d practice games out of an allotted 100,000. practice success rate so far = %.3f' % (total_practice_runs, practice_success_rate))
# Out:
# Successfully start a new game! Game ID: 4839cde1c6fb. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '4839cde1c6fb', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ _ _ _ _ _ _ _ '}
# Guessing letter: i
# Sever response: {'game_id': '4839cde1c6fb', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ _ _ _ i _ i _ '}
# Guessing letter: t
# Sever response: {'game_id': '4839cde1c6fb', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ t _ _ _ _ _ _ i t i _ '}
# Guessing letter: a
# Sever response: {'game_id': '4839cde1c6fb', 'status': 'ongoing', 'tries_remains': 5, 'word': 'a _ t a _ _ _ _ _ i t i _ '}
# Guessing letter: n
# Sever response: {'game_id': '4839cde1c6fb', 'status': 'ongoing', 'tries_remains': 5, 'word': 'a n t a _ _ _ _ _ i t i _ '}
# Guessing letter: l
# Sever response: {'game_id': '4839cde1c6fb', 'status': 'ongoing', 'tries_remains': 4, 'word': 'a n t a _ _ _ _ _ i t i _ '}
# Guessing letter: o
# Sever response: {'game_id': '4839cde1c6fb', 'status': 'ongoing', 'tries_remains': 4, 'word': 'a n t a _ _ _ o _ i t i _ '}
# Guessing letter: s
# Sever response: {'game_id': '4839cde1c6fb', 'status': 'ongoing', 'tries_remains': 3, 'word': 'a n t a _ _ _ o _ i t i _ '}
# Guessing letter: c
# Sever response: {'game_id': '4839cde1c6fb', 'status': 'ongoing', 'tries_remains': 3, 'word': 'a n t a _ _ _ o _ i t i c '}
# Guessing letter: r
# Sever response: {'game_id': '4839cde1c6fb', 'status': 'ongoing', 'tries_remains': 3, 'word': 'a n t a _ _ r o _ i t i c '}
# Guessing letter: p
# Sever response: {'game_id': '4839cde1c6fb', 'status': 'ongoing', 'tries_remains': 3, 'word': 'a n t a p _ r o _ i t i c '}
# Guessing letter: h
# Sever response: {'game_id': '4839cde1c6fb', 'status': 'ongoing', 'tries_remains': 3, 'word': 'a n t a p h r o _ i t i c '}
# Guessing letter: d
# Sever response: {'game_id': '4839cde1c6fb', 'status': 'success', 'tries_remains': 3, 'word': 'a n t a p h r o d i t i c '}
# Successfully finished game: 4839cde1c6fb
# run 3506 practice games out of an allotted 100,000. practice success rate so far = 0.637

# %%
total,s=total_practice_runs,total_practice_successes
for i in range(200):
    api.start_game(practice=1,verbose=True)
    [total_practice_runs,total_recorded_runs,total_recorded_successes,total_practice_successes] = api.my_status() # Get my game stats: (# of tries, # of wins)
    practice_success_rate = (total_practice_successes-s) / (total_practice_runs-total)*100
    time.sleep(0.5)
    print(f"{practice_success_rate:.2f} {total_practice_successes - s} {total_practice_runs - total}", end="\r")

# %%
print(total_practice_runs,total_recorded_runs,total_recorded_successes,total_practice_successes)
# Out:
# 3711 595 384 2366

# %%
m=api.my_status()
total,s=m[0],m[3]
for i in range(400):
    api.start_game(practice=1,verbose=False)
    # api.start_game(practice=1,verbose=True)
    [total_practice_runs,total_recorded_runs,total_recorded_successes,total_practice_successes] = api.my_status() # Get my game stats: (# of tries, # of wins)
    practice_success_rate = (total_practice_successes-s) / (total_practice_runs-total)*100
    # time.sleep(0.5)
    print(f"{practice_success_rate:.2f} {total_practice_runs} {i} ", end="\r")

# %% [markdown]
# ## Playing recorded games:
# Please finalize your code prior to running the cell below. Once this code executes once successfully your submission will be finalized. Our system will not allow you to rerun any additional games.
#
# Please note that it is expected that after you successfully run this block of code that subsequent runs will result in the error message "Your account has been deactivated".
#
# Once you've run this section of the code your submission is complete. Please send us your source code via email.

# %%
for i in range(2,1000):
    api.start_game(practice=0,verbose=False)
    # api.start_game(practice=1,verbose=True)
    [total_practice_runs,total_recorded_runs,total_recorded_successes,total_practice_successes] = api.my_status() # Get my game stats: (# of tries, # of wins)
    rec_success_rate = (total_recorded_successes) / (total_recorded_runs)*100
    # time.sleep(0.5)
    print(f"Playing {i}th game | Success Rate: {rec_success_rate:.2f} ")
# Out:
# Playing 2th game | Success Rate: 33.33
# Playing 3th game | Success Rate: 50.00
# Playing 4th game | Success Rate: 60.00
# Playing 5th game | Success Rate: 66.67
# Playing 6th game | Success Rate: 71.43
# Playing 7th game | Success Rate: 75.00
# Playing 8th game | Success Rate: 77.78
# Playing 9th game | Success Rate: 70.00
# Playing 10th game | Success Rate: 72.73
# Playing 11th game | Success Rate: 75.00
# Playing 12th game | Success Rate: 76.92
# Playing 13th game | Success Rate: 78.57
# Playing 14th game | Success Rate: 73.33
# Playing 15th game | Success Rate: 68.75
# Playing 16th game | Success Rate: 64.71
# Playing 17th game | Success Rate: 66.67
# Playing 18th game | Success Rate: 68.42
# Playing 19th game | Success Rate: 70.00
# Playing 20th game | Success Rate: 66.67
# Playing 21th game | Success Rate: 68.18
# Playing 22th game | Success Rate: 69.57
# Playing 23th game | Success Rate: 70.83
# Playing 24th game | Success Rate: 68.00
# Playing 25th game | Success Rate: 65.38
# Playing 26th game | Success Rate: 66.67
# Playing 27th game | Success Rate: 67.86
# Playing 28th game | Success Rate: 65.52
# Playing 29th game | Success Rate: 66.67
# Playing 30th game | Success Rate: 67.74
# Playing 31th game | Success Rate: 68.75
# Playing 32th game | Success Rate: 69.70
# Playing 33th game | Success Rate: 67.65
# Playing 34th game | Success Rate: 65.71
# Playing 35th game | Success Rate: 66.67
# Playing 36th game | Success Rate: 64.86
# Playing 37th game | Success Rate: 65.79
# Playing 38th game | Success Rate: 66.67
# Playing 39th game | Success Rate: 67.50
# Playing 40th game | Success Rate: 68.29
# Playing 41th game | Success Rate: 69.05
# Playing 42th game | Success Rate: 69.77
# Playing 43th game | Success Rate: 68.18
# Playing 44th game | Success Rate: 66.67
# Playing 45th game | Success Rate: 67.39
# Playing 46th game | Success Rate: 68.09
# Playing 47th game | Success Rate: 68.75
# Playing 48th game | Success Rate: 67.35
# Playing 49th game | Success Rate: 68.00
# Playing 50th game | Success Rate: 68.63
# Playing 51th game | Success Rate: 69.23
# Playing 52th game | Success Rate: 69.81
# Playing 53th game | Success Rate: 70.37
# Playing 54th game | Success Rate: 70.91
# Playing 55th game | Success Rate: 71.43
# Playing 56th game | Success Rate: 71.93
# Playing 57th game | Success Rate: 72.41
# Playing 58th game | Success Rate: 72.88
# Playing 59th game | Success Rate: 73.33
# Playing 60th game | Success Rate: 73.77
# Playing 61th game | Success Rate: 74.19
# Playing 62th game | Success Rate: 74.60
# Playing 63th game | Success Rate: 75.00
# Playing 64th game | Success Rate: 75.38
# Playing 65th game | Success Rate: 74.24
# Playing 66th game | Success Rate: 73.13
# Playing 67th game | Success Rate: 73.53
# Playing 68th game | Success Rate: 73.91
# Playing 69th game | Success Rate: 74.29
# Playing 70th game | Success Rate: 73.24
# Playing 71th game | Success Rate: 73.61
# Playing 72th game | Success Rate: 73.97
# Playing 73th game | Success Rate: 72.97
# Playing 74th game | Success Rate: 73.33
# Playing 75th game | Success Rate: 73.68
# Playing 76th game | Success Rate: 74.03
# Playing 77th game | Success Rate: 73.08
# Playing 78th game | Success Rate: 72.15
# Playing 79th game | Success Rate: 71.25
# Playing 80th game | Success Rate: 70.37
# Playing 81th game | Success Rate: 69.51
# Playing 82th game | Success Rate: 68.67
# Playing 83th game | Success Rate: 69.05
# Playing 84th game | Success Rate: 69.41
# Playing 85th game | Success Rate: 69.77
# Playing 86th game | Success Rate: 68.97
# Playing 87th game | Success Rate: 69.32
# Playing 88th game | Success Rate: 69.66
# Playing 89th game | Success Rate: 70.00
# Playing 90th game | Success Rate: 70.33
# Playing 91th game | Success Rate: 70.65
# Playing 92th game | Success Rate: 70.97
# Playing 93th game | Success Rate: 71.28
# Playing 94th game | Success Rate: 70.53
# Playing 95th game | Success Rate: 70.83
# Playing 96th game | Success Rate: 70.10
# Playing 97th game | Success Rate: 70.41
# Playing 98th game | Success Rate: 69.70
# Playing 99th game | Success Rate: 70.00
# Playing 100th game | Success Rate: 69.31
# Playing 101th game | Success Rate: 69.61
# Playing 102th game | Success Rate: 69.90
# Playing 103th game | Success Rate: 70.19
# Playing 104th game | Success Rate: 69.52
# Playing 105th game | Success Rate: 69.81
# Playing 106th game | Success Rate: 69.16
# Playing 107th game | Success Rate: 69.44
# Playing 108th game | Success Rate: 69.72
# Playing 109th game | Success Rate: 70.00
# Playing 110th game | Success Rate: 69.37
# Playing 111th game | Success Rate: 69.64
# Playing 112th game | Success Rate: 69.03
# Playing 113th game | Success Rate: 68.42
# Playing 114th game | Success Rate: 67.83
# Playing 115th game | Success Rate: 68.10
# Playing 116th game | Success Rate: 67.52
# Playing 117th game | Success Rate: 66.95
# Playing 118th game | Success Rate: 67.23
# Playing 119th game | Success Rate: 66.67
# Playing 120th game | Success Rate: 66.94
# Playing 121th game | Success Rate: 67.21
# Playing 122th game | Success Rate: 66.67
# Playing 123th game | Success Rate: 66.94
# Playing 124th game | Success Rate: 67.20
# Playing 125th game | Success Rate: 66.67
# Playing 126th game | Success Rate: 66.14
# Playing 127th game | Success Rate: 66.41
# Playing 128th game | Success Rate: 66.67
# Playing 129th game | Success Rate: 66.92
# Playing 130th game | Success Rate: 66.41
# Playing 131th game | Success Rate: 66.67
# Playing 132th game | Success Rate: 66.92
# Playing 133th game | Success Rate: 67.16
# Playing 134th game | Success Rate: 67.41
# Playing 135th game | Success Rate: 67.65
# Playing 136th game | Success Rate: 67.88
# Playing 137th game | Success Rate: 68.12
# Playing 138th game | Success Rate: 68.35
# Playing 139th game | Success Rate: 68.57
# Playing 140th game | Success Rate: 68.09
# Playing 141th game | Success Rate: 67.61
# Playing 142th game | Success Rate: 67.83
# Playing 143th game | Success Rate: 67.36
# Playing 144th game | Success Rate: 67.59
# Playing 145th game | Success Rate: 67.12
# Playing 146th game | Success Rate: 67.35
# Playing 147th game | Success Rate: 67.57
# Playing 148th game | Success Rate: 67.79
# Playing 149th game | Success Rate: 67.33
# Playing 150th game | Success Rate: 67.55
# Playing 151th game | Success Rate: 67.11
# Playing 152th game | Success Rate: 67.32
# Playing 153th game | Success Rate: 67.53
# Playing 154th game | Success Rate: 67.10
# Playing 155th game | Success Rate: 67.31
# Playing 156th game | Success Rate: 67.52
# Playing 157th game | Success Rate: 67.09
# Playing 158th game | Success Rate: 66.67
# Playing 159th game | Success Rate: 66.88
# Playing 160th game | Success Rate: 67.08
# Playing 161th game | Success Rate: 66.67
# Playing 162th game | Success Rate: 66.87
# Playing 163th game | Success Rate: 66.46
# Playing 164th game | Success Rate: 66.67
# Playing 165th game | Success Rate: 66.87
# Playing 166th game | Success Rate: 67.07
# Playing 167th game | Success Rate: 67.26
# Playing 168th game | Success Rate: 67.46
# Playing 169th game | Success Rate: 67.65
# Playing 170th game | Success Rate: 67.84
# Playing 171th game | Success Rate: 67.44
# Playing 172th game | Success Rate: 67.63
# Playing 173th game | Success Rate: 67.24
# Playing 174th game | Success Rate: 67.43
# Playing 175th game | Success Rate: 67.61
# Playing 176th game | Success Rate: 67.80
# Playing 177th game | Success Rate: 67.98
# Playing 178th game | Success Rate: 68.16
# Playing 179th game | Success Rate: 68.33
# Playing 180th game | Success Rate: 67.96
# Playing 181th game | Success Rate: 68.13
# Playing 182th game | Success Rate: 67.76
# Playing 183th game | Success Rate: 67.93
# Playing 184th game | Success Rate: 68.11
# Playing 185th game | Success Rate: 68.28
# Playing 186th game | Success Rate: 68.45
# Playing 187th game | Success Rate: 68.09
# Playing 188th game | Success Rate: 68.25
# Playing 189th game | Success Rate: 67.89
# Playing 190th game | Success Rate: 68.06
# Playing 191th game | Success Rate: 68.23
# Playing 192th game | Success Rate: 68.39
# Playing 193th game | Success Rate: 68.56
# Playing 194th game | Success Rate: 68.72
# Playing 195th game | Success Rate: 68.88
# Playing 196th game | Success Rate: 68.53
# Playing 197th game | Success Rate: 68.18
# Playing 198th game | Success Rate: 67.84
# Playing 199th game | Success Rate: 68.00
# Playing 200th game | Success Rate: 68.16
# Playing 201th game | Success Rate: 67.82
# Playing 202th game | Success Rate: 67.49
# Playing 203th game | Success Rate: 67.65
# Playing 204th game | Success Rate: 67.80
# Playing 205th game | Success Rate: 67.96
# Playing 206th game | Success Rate: 68.12
# Playing 207th game | Success Rate: 68.27
# Playing 208th game | Success Rate: 67.94
# Playing 209th game | Success Rate: 68.10
# Playing 210th game | Success Rate: 68.25
# Playing 211th game | Success Rate: 67.92
# Playing 212th game | Success Rate: 67.61
# Playing 213th game | Success Rate: 67.29
# Playing 214th game | Success Rate: 67.44
# Playing 215th game | Success Rate: 67.13
# Playing 216th game | Success Rate: 66.82
# Playing 217th game | Success Rate: 66.51
# Playing 218th game | Success Rate: 66.21
# Playing 219th game | Success Rate: 65.91
# Playing 220th game | Success Rate: 66.06
# Playing 221th game | Success Rate: 66.22
# Playing 222th game | Success Rate: 66.37
# Playing 223th game | Success Rate: 66.07
# Playing 224th game | Success Rate: 65.78
# Playing 225th game | Success Rate: 65.49
# Playing 226th game | Success Rate: 65.64
# Playing 227th game | Success Rate: 65.79
# Playing 228th game | Success Rate: 65.94
# Playing 229th game | Success Rate: 66.09
# Playing 230th game | Success Rate: 66.23
# Playing 231th game | Success Rate: 65.95
# Playing 232th game | Success Rate: 65.67
# Playing 233th game | Success Rate: 65.81
# Playing 234th game | Success Rate: 65.53
# Playing 235th game | Success Rate: 65.68
# Playing 236th game | Success Rate: 65.40
# Playing 237th game | Success Rate: 65.55
# Playing 238th game | Success Rate: 65.27
# Playing 239th game | Success Rate: 65.42
# Playing 240th game | Success Rate: 65.56
# Playing 241th game | Success Rate: 65.29
# Playing 242th game | Success Rate: 65.43
# Playing 243th game | Success Rate: 65.57
# Playing 244th game | Success Rate: 65.71
# Playing 245th game | Success Rate: 65.45
# Playing 246th game | Success Rate: 65.59
# Playing 247th game | Success Rate: 65.32
# Playing 248th game | Success Rate: 65.06
# Playing 249th game | Success Rate: 65.20
# Playing 250th game | Success Rate: 65.34
# Playing 251th game | Success Rate: 65.48
# Playing 252th game | Success Rate: 65.22
# Playing 253th game | Success Rate: 64.96
# Playing 254th game | Success Rate: 65.10
# Playing 255th game | Success Rate: 65.23
# Playing 256th game | Success Rate: 64.98
# Playing 257th game | Success Rate: 64.73
# Playing 258th game | Success Rate: 64.86
# Playing 259th game | Success Rate: 65.00
# Playing 260th game | Success Rate: 64.75
# Playing 261th game | Success Rate: 64.89
# Playing 262th game | Success Rate: 65.02
# Playing 263th game | Success Rate: 64.77
# Playing 264th game | Success Rate: 64.91
# Playing 265th game | Success Rate: 65.04
# Playing 266th game | Success Rate: 65.17
# Playing 267th game | Success Rate: 65.30
# Playing 268th game | Success Rate: 65.43
# Playing 269th game | Success Rate: 65.56
# Playing 270th game | Success Rate: 65.68
# Playing 271th game | Success Rate: 65.81
# Playing 272th game | Success Rate: 65.93
# Playing 273th game | Success Rate: 66.06
# Playing 274th game | Success Rate: 66.18
# Playing 275th game | Success Rate: 65.94
# Playing 276th game | Success Rate: 66.06
# Playing 277th game | Success Rate: 66.19
# Playing 278th game | Success Rate: 66.31
# Playing 279th game | Success Rate: 66.07
# Playing 280th game | Success Rate: 66.19
# Playing 281th game | Success Rate: 65.96
# Playing 282th game | Success Rate: 66.08
# Playing 283th game | Success Rate: 66.20
# Playing 284th game | Success Rate: 66.32
# Playing 285th game | Success Rate: 66.08
# Playing 286th game | Success Rate: 65.85
# Playing 287th game | Success Rate: 65.62
# Playing 288th game | Success Rate: 65.74
# Playing 289th game | Success Rate: 65.86
# Playing 290th game | Success Rate: 65.64
# Playing 291th game | Success Rate: 65.75
# Playing 292th game | Success Rate: 65.53
# Playing 293th game | Success Rate: 65.65
# Playing 294th game | Success Rate: 65.76
# Playing 295th game | Success Rate: 65.88
# Playing 296th game | Success Rate: 65.99
# Playing 297th game | Success Rate: 66.11
# Playing 298th game | Success Rate: 65.89
# Playing 299th game | Success Rate: 66.00
# Playing 300th game | Success Rate: 66.11
# Playing 301th game | Success Rate: 65.89
# Playing 302th game | Success Rate: 66.01
# Playing 303th game | Success Rate: 66.12
# Playing 304th game | Success Rate: 66.23
# Playing 305th game | Success Rate: 66.01
# Playing 306th game | Success Rate: 66.12
# Playing 307th game | Success Rate: 66.23
# Playing 308th game | Success Rate: 66.34
# Playing 309th game | Success Rate: 66.45
# Playing 310th game | Success Rate: 66.56
# Playing 311th game | Success Rate: 66.35
# Playing 312th game | Success Rate: 66.13
# Playing 313th game | Success Rate: 66.24
# Playing 314th game | Success Rate: 66.35
# Playing 315th game | Success Rate: 66.46
# Playing 316th game | Success Rate: 66.25
# Playing 317th game | Success Rate: 66.04
# Playing 318th game | Success Rate: 66.14
# Playing 319th game | Success Rate: 66.25
# Playing 320th game | Success Rate: 66.04
# Playing 321th game | Success Rate: 66.15
# Playing 322th game | Success Rate: 66.25
# Playing 323th game | Success Rate: 66.36
# Playing 324th game | Success Rate: 66.15
# Playing 325th game | Success Rate: 66.26
# Playing 326th game | Success Rate: 66.36
# Playing 327th game | Success Rate: 66.46
# Playing 328th game | Success Rate: 66.57
# Playing 329th game | Success Rate: 66.67
# Playing 330th game | Success Rate: 66.77
# Playing 331th game | Success Rate: 66.57
# Playing 332th game | Success Rate: 66.37
# Playing 333th game | Success Rate: 66.17
# Playing 334th game | Success Rate: 66.27
# Playing 335th game | Success Rate: 66.37
# Playing 336th game | Success Rate: 66.47
# Playing 337th game | Success Rate: 66.27
# Playing 338th game | Success Rate: 66.37
# Playing 339th game | Success Rate: 66.18
# Playing 340th game | Success Rate: 65.98
# Playing 341th game | Success Rate: 66.08
# Playing 342th game | Success Rate: 66.18
# Playing 343th game | Success Rate: 66.28
# Playing 344th game | Success Rate: 66.38
# Playing 345th game | Success Rate: 66.47
# Playing 346th game | Success Rate: 66.57
# Playing 347th game | Success Rate: 66.67
# Playing 348th game | Success Rate: 66.76
# Playing 349th game | Success Rate: 66.57
# Playing 350th game | Success Rate: 66.38
# Playing 351th game | Success Rate: 66.48
# Playing 352th game | Success Rate: 66.29
# Playing 353th game | Success Rate: 66.38
# Playing 354th game | Success Rate: 66.20
# Playing 355th game | Success Rate: 66.01
# Playing 356th game | Success Rate: 66.11
# Playing 357th game | Success Rate: 66.20
# Playing 358th game | Success Rate: 66.30
# Playing 359th game | Success Rate: 66.39
# Playing 360th game | Success Rate: 66.48
# Playing 361th game | Success Rate: 66.57
# Playing 362th game | Success Rate: 66.39
# Playing 363th game | Success Rate: 66.48
# Playing 364th game | Success Rate: 66.58
# Playing 365th game | Success Rate: 66.39
# Playing 366th game | Success Rate: 66.49
# Playing 367th game | Success Rate: 66.58
# Playing 368th game | Success Rate: 66.40
# Playing 369th game | Success Rate: 66.22
# Playing 370th game | Success Rate: 66.31
# Playing 371th game | Success Rate: 66.40
# Playing 372th game | Success Rate: 66.22
# Playing 373th game | Success Rate: 66.04
# Playing 374th game | Success Rate: 66.13
# Playing 375th game | Success Rate: 66.22
# Playing 376th game | Success Rate: 66.31
# Playing 377th game | Success Rate: 66.40
# Playing 378th game | Success Rate: 66.49
# Playing 379th game | Success Rate: 66.58
# Playing 380th game | Success Rate: 66.67
# Playing 381th game | Success Rate: 66.49
# Playing 382th game | Success Rate: 66.58
# Playing 383th game | Success Rate: 66.67
# Playing 384th game | Success Rate: 66.75
# Playing 385th game | Success Rate: 66.58
# Playing 386th game | Success Rate: 66.67
# Playing 387th game | Success Rate: 66.75
# Playing 388th game | Success Rate: 66.58
# Playing 389th game | Success Rate: 66.41
# Playing 390th game | Success Rate: 66.24
# Playing 391th game | Success Rate: 66.33
# Playing 392th game | Success Rate: 66.41
# Playing 393th game | Success Rate: 66.50
# Playing 394th game | Success Rate: 66.33
# Playing 395th game | Success Rate: 66.16
# Playing 396th game | Success Rate: 66.25
# Playing 397th game | Success Rate: 66.08
# Playing 398th game | Success Rate: 66.17
# Playing 399th game | Success Rate: 66.00
# Playing 400th game | Success Rate: 65.84
# Playing 401th game | Success Rate: 65.67
# Playing 402th game | Success Rate: 65.51
# Playing 403th game | Success Rate: 65.59
# Playing 404th game | Success Rate: 65.68
# Playing 405th game | Success Rate: 65.76
# Playing 406th game | Success Rate: 65.85
# Playing 407th game | Success Rate: 65.69
# Playing 408th game | Success Rate: 65.77
# Playing 409th game | Success Rate: 65.61
# Playing 410th game | Success Rate: 65.69
# Playing 411th game | Success Rate: 65.78
# Playing 412th game | Success Rate: 65.86
# Playing 413th game | Success Rate: 65.94
# Playing 414th game | Success Rate: 66.02
# Playing 415th game | Success Rate: 66.11
# Playing 416th game | Success Rate: 65.95
# Playing 417th game | Success Rate: 66.03
# Playing 418th game | Success Rate: 66.11
# Playing 419th game | Success Rate: 66.19
# Playing 420th game | Success Rate: 66.27
# Playing 421th game | Success Rate: 66.35
# Playing 422th game | Success Rate: 66.43
# Playing 423th game | Success Rate: 66.51
# Playing 424th game | Success Rate: 66.59
# Playing 425th game | Success Rate: 66.43
# Playing 426th game | Success Rate: 66.28
# Playing 427th game | Success Rate: 66.36
# Playing 428th game | Success Rate: 66.43
# Playing 429th game | Success Rate: 66.51
# Playing 430th game | Success Rate: 66.59
# Playing 431th game | Success Rate: 66.67
# Playing 432th game | Success Rate: 66.51
# Playing 433th game | Success Rate: 66.59
# Playing 434th game | Success Rate: 66.67
# Playing 435th game | Success Rate: 66.74
# Playing 436th game | Success Rate: 66.59
# Playing 437th game | Success Rate: 66.67
# Playing 438th game | Success Rate: 66.74
# Playing 439th game | Success Rate: 66.82
# Playing 440th game | Success Rate: 66.89
# Playing 441th game | Success Rate: 66.97
# Playing 442th game | Success Rate: 67.04
# Playing 443th game | Success Rate: 66.89
# Playing 444th game | Success Rate: 66.97
# Playing 445th game | Success Rate: 66.82
# Playing 446th game | Success Rate: 66.89
# Playing 447th game | Success Rate: 66.74
# Playing 448th game | Success Rate: 66.59
# Playing 449th game | Success Rate: 66.67
# Playing 450th game | Success Rate: 66.74
# Playing 451th game | Success Rate: 66.59
# Playing 452th game | Success Rate: 66.45
# Playing 453th game | Success Rate: 66.52
# Playing 454th game | Success Rate: 66.59
# Playing 455th game | Success Rate: 66.45
# Playing 456th game | Success Rate: 66.52
# Playing 457th game | Success Rate: 66.38
# Playing 458th game | Success Rate: 66.45
# Playing 459th game | Success Rate: 66.52
# Playing 460th game | Success Rate: 66.59
# Playing 461th game | Success Rate: 66.67
# Playing 462th game | Success Rate: 66.52
# Playing 463th game | Success Rate: 66.38
# Playing 464th game | Success Rate: 66.24
# Playing 465th game | Success Rate: 66.31
# Playing 466th game | Success Rate: 66.38
# Playing 467th game | Success Rate: 66.24
# Playing 468th game | Success Rate: 66.31
# Playing 469th game | Success Rate: 66.38
# Playing 470th game | Success Rate: 66.45
# Playing 471th game | Success Rate: 66.53
# Playing 472th game | Success Rate: 66.38
# Playing 473th game | Success Rate: 66.46
# Playing 474th game | Success Rate: 66.53
# Playing 475th game | Success Rate: 66.60
# Playing 476th game | Success Rate: 66.67
# Playing 477th game | Success Rate: 66.74
# Playing 478th game | Success Rate: 66.60
# Playing 479th game | Success Rate: 66.67
# Playing 480th game | Success Rate: 66.74
# Playing 481th game | Success Rate: 66.80
# Playing 482th game | Success Rate: 66.87
# Playing 483th game | Success Rate: 66.94
# Playing 484th game | Success Rate: 67.01
# Playing 485th game | Success Rate: 67.08
# Playing 486th game | Success Rate: 66.94
# Playing 487th game | Success Rate: 67.01
# Playing 488th game | Success Rate: 66.87
# Playing 489th game | Success Rate: 66.73
# Playing 490th game | Success Rate: 66.60
# Playing 491th game | Success Rate: 66.46
# Playing 492th game | Success Rate: 66.33
# Playing 493th game | Success Rate: 66.19
# Playing 494th game | Success Rate: 66.26
# Playing 495th game | Success Rate: 66.13
# Playing 496th game | Success Rate: 66.20
# Playing 497th game | Success Rate: 66.06
# Playing 498th game | Success Rate: 65.93
# Playing 499th game | Success Rate: 65.80
# Playing 500th game | Success Rate: 65.87
# Playing 501th game | Success Rate: 65.74
# Playing 502th game | Success Rate: 65.81
# Playing 503th game | Success Rate: 65.67
# Playing 504th game | Success Rate: 65.74
# Playing 505th game | Success Rate: 65.61
# Playing 506th game | Success Rate: 65.48
# Playing 507th game | Success Rate: 65.35
# Playing 508th game | Success Rate: 65.42
# Playing 509th game | Success Rate: 65.29
# Playing 510th game | Success Rate: 65.36
# Playing 511th game | Success Rate: 65.23
# Playing 512th game | Success Rate: 65.30
# Playing 513th game | Success Rate: 65.37
# Playing 514th game | Success Rate: 65.44
# Playing 515th game | Success Rate: 65.50
# Playing 516th game | Success Rate: 65.38
# Playing 517th game | Success Rate: 65.44
# Playing 518th game | Success Rate: 65.51
# Playing 519th game | Success Rate: 65.38
# Playing 520th game | Success Rate: 65.45
# Playing 521th game | Success Rate: 65.33
# Playing 522th game | Success Rate: 65.39
# Playing 523th game | Success Rate: 65.27
# Playing 524th game | Success Rate: 65.14
# Playing 525th game | Success Rate: 65.02
# Playing 526th game | Success Rate: 65.09
# Playing 527th game | Success Rate: 65.15
# Playing 528th game | Success Rate: 65.22
# Playing 529th game | Success Rate: 65.09
# Playing 530th game | Success Rate: 65.16
# Playing 531th game | Success Rate: 65.23
# Playing 532th game | Success Rate: 65.29
# Playing 533th game | Success Rate: 65.36
# Playing 534th game | Success Rate: 65.42
# Playing 535th game | Success Rate: 65.49
# Playing 536th game | Success Rate: 65.55
# Playing 537th game | Success Rate: 65.61
# Playing 538th game | Success Rate: 65.68
# Playing 539th game | Success Rate: 65.74
# Playing 540th game | Success Rate: 65.80
# Playing 541th game | Success Rate: 65.68
# Playing 542th game | Success Rate: 65.75
# Playing 543th game | Success Rate: 65.81
# Playing 544th game | Success Rate: 65.87
# Playing 545th game | Success Rate: 65.75
# Playing 546th game | Success Rate: 65.81
# Playing 547th game | Success Rate: 65.69
# Playing 548th game | Success Rate: 65.57
# Playing 549th game | Success Rate: 65.45
# Playing 550th game | Success Rate: 65.52
# Playing 551th game | Success Rate: 65.58
# Playing 552th game | Success Rate: 65.64
# Playing 553th game | Success Rate: 65.70
# Playing 554th game | Success Rate: 65.77
# Playing 555th game | Success Rate: 65.65
# Playing 556th game | Success Rate: 65.53
# Playing 557th game | Success Rate: 65.59
# Playing 558th game | Success Rate: 65.47
# Playing 559th game | Success Rate: 65.54
# Playing 560th game | Success Rate: 65.60
# Playing 561th game | Success Rate: 65.66
# Playing 562th game | Success Rate: 65.54
# Playing 563th game | Success Rate: 65.43
# Playing 564th game | Success Rate: 65.31
# Playing 565th game | Success Rate: 65.19
# Playing 566th game | Success Rate: 65.26
# Playing 567th game | Success Rate: 65.14
# Playing 568th game | Success Rate: 65.03
# Playing 569th game | Success Rate: 65.09
# Playing 570th game | Success Rate: 65.15
# Playing 571th game | Success Rate: 65.03
# Playing 572th game | Success Rate: 64.92
# Playing 573th game | Success Rate: 64.81
# Playing 574th game | Success Rate: 64.87
# Playing 575th game | Success Rate: 64.93
# Playing 576th game | Success Rate: 64.99
# Playing 577th game | Success Rate: 65.05

# %%
for i in range(594,1000):
    api.start_game(practice=0,verbose=False)
    # api.start_game(practice=1,verbose=True)
    [total_practice_runs,total_recorded_runs,total_recorded_successes,total_practice_successes] = api.my_status() # Get my game stats: (# of tries, # of wins)
    rec_success_rate = (total_recorded_successes) / (total_recorded_runs)*100
    # time.sleep(0.5)
    print(f"Playing {i}th game | Success Rate: {rec_success_rate:.2f} ")
# Out:
# Playing 594th game | Success Rate: 64.43
# Playing 595th game | Success Rate: 64.32
# Playing 596th game | Success Rate: 64.38
# Playing 597th game | Success Rate: 64.44
# Playing 598th game | Success Rate: 64.50
# Playing 599th game | Success Rate: 64.39
# Playing 600th game | Success Rate: 64.45
# Playing 601th game | Success Rate: 64.51
# Playing 602th game | Success Rate: 64.57
# Playing 603th game | Success Rate: 64.63
# Playing 604th game | Success Rate: 64.69
# Playing 605th game | Success Rate: 64.74
# Playing 606th game | Success Rate: 64.64
# Playing 607th game | Success Rate: 64.53
# Playing 608th game | Success Rate: 64.59
# Playing 609th game | Success Rate: 64.48
# Playing 610th game | Success Rate: 64.54
# Playing 611th game | Success Rate: 64.44
# Playing 612th game | Success Rate: 64.50
# Playing 613th game | Success Rate: 64.55
# Playing 614th game | Success Rate: 64.45
# Playing 615th game | Success Rate: 64.51
# Playing 616th game | Success Rate: 64.56
# Playing 617th game | Success Rate: 64.62
# Playing 618th game | Success Rate: 64.68
# Playing 619th game | Success Rate: 64.57
# Playing 620th game | Success Rate: 64.63
# Playing 621th game | Success Rate: 64.69
# Playing 622th game | Success Rate: 64.74
# Playing 623th game | Success Rate: 64.80
# Playing 624th game | Success Rate: 64.86
# Playing 625th game | Success Rate: 64.75
# Playing 626th game | Success Rate: 64.81
# Playing 627th game | Success Rate: 64.86
# Playing 628th game | Success Rate: 64.92
# Playing 629th game | Success Rate: 64.98
# Playing 630th game | Success Rate: 65.03
# Playing 631th game | Success Rate: 65.09
# Playing 632th game | Success Rate: 65.14
# Playing 633th game | Success Rate: 65.20
# Playing 634th game | Success Rate: 65.25
# Playing 635th game | Success Rate: 65.15
# Playing 636th game | Success Rate: 65.05
# Playing 637th game | Success Rate: 64.95
# Playing 638th game | Success Rate: 65.00
# Playing 639th game | Success Rate: 64.90
# Playing 640th game | Success Rate: 64.80
# Playing 641th game | Success Rate: 64.85
# Playing 642th game | Success Rate: 64.91
# Playing 643th game | Success Rate: 64.96
# Playing 644th game | Success Rate: 65.02
# Playing 645th game | Success Rate: 65.07
# Playing 646th game | Success Rate: 65.12
# Playing 647th game | Success Rate: 65.02
# Playing 648th game | Success Rate: 64.92
# Playing 649th game | Success Rate: 64.82
# Playing 650th game | Success Rate: 64.88
# Playing 651th game | Success Rate: 64.93
# Playing 652th game | Success Rate: 64.98
# Playing 653th game | Success Rate: 65.04
# Playing 654th game | Success Rate: 65.09
# Playing 655th game | Success Rate: 64.99
# Playing 656th game | Success Rate: 64.89
# Playing 657th game | Success Rate: 64.80
# Playing 658th game | Success Rate: 64.70
# Playing 659th game | Success Rate: 64.75
# Playing 660th game | Success Rate: 64.80
# Playing 661th game | Success Rate: 64.86
# Playing 662th game | Success Rate: 64.76
# Playing 663th game | Success Rate: 64.81
# Playing 664th game | Success Rate: 64.71
# Playing 665th game | Success Rate: 64.77
# Playing 666th game | Success Rate: 64.82
# Playing 667th game | Success Rate: 64.87
# Playing 668th game | Success Rate: 64.93
# Playing 669th game | Success Rate: 64.98
# Playing 670th game | Success Rate: 64.88
# Playing 671th game | Success Rate: 64.78
# Playing 672th game | Success Rate: 64.69
# Playing 673th game | Success Rate: 64.59
# Playing 674th game | Success Rate: 64.64
# Playing 675th game | Success Rate: 64.70
# Playing 676th game | Success Rate: 64.75
# Playing 677th game | Success Rate: 64.80
# Playing 678th game | Success Rate: 64.85
# Playing 679th game | Success Rate: 64.76
# Playing 680th game | Success Rate: 64.81
# Playing 681th game | Success Rate: 64.71
# Playing 682th game | Success Rate: 64.62
# Playing 683th game | Success Rate: 64.53
# Playing 684th game | Success Rate: 64.58
# Playing 685th game | Success Rate: 64.63
# Playing 686th game | Success Rate: 64.68
# Playing 687th game | Success Rate: 64.73
# Playing 689th game | Success Rate: 64.54
# Playing 690th game | Success Rate: 64.60
# Playing 691th game | Success Rate: 64.65
# Playing 692th game | Success Rate: 64.70
# Playing 693th game | Success Rate: 64.75
# Playing 694th game | Success Rate: 64.80
# Playing 695th game | Success Rate: 64.85
# Playing 696th game | Success Rate: 64.76
# Playing 697th game | Success Rate: 64.81
# Playing 698th game | Success Rate: 64.86
# Playing 699th game | Success Rate: 64.76
# Playing 700th game | Success Rate: 64.81
# Playing 701th game | Success Rate: 64.72
# Playing 702th game | Success Rate: 64.77
# Playing 703th game | Success Rate: 64.82
# Playing 704th game | Success Rate: 64.73
# Playing 705th game | Success Rate: 64.78
# Playing 706th game | Success Rate: 64.69
# Playing 707th game | Success Rate: 64.74
# Playing 708th game | Success Rate: 64.79
# Playing 709th game | Success Rate: 64.70
# Playing 710th game | Success Rate: 64.75
# Playing 711th game | Success Rate: 64.80
# Playing 712th game | Success Rate: 64.85
# Playing 713th game | Success Rate: 64.90
# Playing 714th game | Success Rate: 64.80
# Playing 715th game | Success Rate: 64.85
# Playing 716th game | Success Rate: 64.76
# Playing 717th game | Success Rate: 64.81
# Playing 718th game | Success Rate: 64.86
# Playing 719th game | Success Rate: 64.91
# Playing 720th game | Success Rate: 64.96
# Playing 721th game | Success Rate: 65.01
# Playing 722th game | Success Rate: 65.06
# Playing 723th game | Success Rate: 65.10
# Playing 724th game | Success Rate: 65.15
# Playing 725th game | Success Rate: 65.06
# Playing 726th game | Success Rate: 65.11
# Playing 727th game | Success Rate: 65.16
# Playing 728th game | Success Rate: 65.21
# Playing 729th game | Success Rate: 65.25
# Playing 730th game | Success Rate: 65.30
# Playing 731th game | Success Rate: 65.35
# Playing 732th game | Success Rate: 65.26
# Playing 733th game | Success Rate: 65.31
# Playing 734th game | Success Rate: 65.35
# Playing 735th game | Success Rate: 65.26
# Playing 736th game | Success Rate: 65.31
# Playing 737th game | Success Rate: 65.36
# Playing 738th game | Success Rate: 65.41
# Playing 739th game | Success Rate: 65.45
# Playing 740th game | Success Rate: 65.50
# Playing 741th game | Success Rate: 65.41
# Playing 742th game | Success Rate: 65.46
# Playing 743th game | Success Rate: 65.50
# Playing 744th game | Success Rate: 65.42
# Playing 745th game | Success Rate: 65.46
# Playing 746th game | Success Rate: 65.37
# Playing 747th game | Success Rate: 65.42
# Playing 748th game | Success Rate: 65.33
# Playing 749th game | Success Rate: 65.38
# Playing 750th game | Success Rate: 65.29
# Playing 751th game | Success Rate: 65.34
# Playing 752th game | Success Rate: 65.38
# Playing 753th game | Success Rate: 65.43
# Playing 754th game | Success Rate: 65.48
# Playing 755th game | Success Rate: 65.39
# Playing 756th game | Success Rate: 65.30
# Playing 757th game | Success Rate: 65.35
# Playing 758th game | Success Rate: 65.26
# Playing 759th game | Success Rate: 65.31
# Playing 760th game | Success Rate: 65.22
# Playing 761th game | Success Rate: 65.27
# Playing 762th game | Success Rate: 65.18
# Playing 763th game | Success Rate: 65.23
# Playing 764th game | Success Rate: 65.27
# Playing 765th game | Success Rate: 65.32
# Playing 766th game | Success Rate: 65.36
# Playing 767th game | Success Rate: 65.28
# Playing 768th game | Success Rate: 65.19
# Playing 769th game | Success Rate: 65.24
# Playing 770th game | Success Rate: 65.16
# Playing 771th game | Success Rate: 65.20
# Playing 772th game | Success Rate: 65.25
# Playing 773th game | Success Rate: 65.29
# Playing 774th game | Success Rate: 65.34
# Playing 775th game | Success Rate: 65.38
# Playing 776th game | Success Rate: 65.42
# Playing 777th game | Success Rate: 65.47
# Playing 778th game | Success Rate: 65.51
# Playing 779th game | Success Rate: 65.56
# Playing 780th game | Success Rate: 65.60
# Playing 781th game | Success Rate: 65.64
# Playing 782th game | Success Rate: 65.69
# Playing 783th game | Success Rate: 65.73
# Playing 784th game | Success Rate: 65.78
# Playing 785th game | Success Rate: 65.82
# Playing 786th game | Success Rate: 65.86
# Playing 787th game | Success Rate: 65.91
# Playing 788th game | Success Rate: 65.95
# Playing 789th game | Success Rate: 65.87
# Playing 790th game | Success Rate: 65.78
# Playing 791th game | Success Rate: 65.83
# Playing 792th game | Success Rate: 65.87
# Playing 793th game | Success Rate: 65.91
# Playing 794th game | Success Rate: 65.95
# Playing 795th game | Success Rate: 65.87
# Playing 796th game | Success Rate: 65.79
# Playing 797th game | Success Rate: 65.83
# Playing 798th game | Success Rate: 65.88
# Playing 799th game | Success Rate: 65.92
# Playing 800th game | Success Rate: 65.96
# Playing 801th game | Success Rate: 66.00
# Playing 802th game | Success Rate: 66.04
# Playing 803th game | Success Rate: 66.09
# Playing 804th game | Success Rate: 66.00
# Playing 805th game | Success Rate: 66.05
# Playing 806th game | Success Rate: 66.09
# Playing 807th game | Success Rate: 66.13
# Playing 808th game | Success Rate: 66.05
# Playing 809th game | Success Rate: 66.09
# Playing 810th game | Success Rate: 66.13
# Playing 811th game | Success Rate: 66.05
# Playing 812th game | Success Rate: 66.09
# Playing 813th game | Success Rate: 66.13
# Playing 814th game | Success Rate: 66.18
# Playing 815th game | Success Rate: 66.22
# Playing 816th game | Success Rate: 66.26
# Playing 817th game | Success Rate: 66.30
# Playing 818th game | Success Rate: 66.34
# Playing 819th game | Success Rate: 66.26
# Playing 820th game | Success Rate: 66.18
# Playing 821th game | Success Rate: 66.10
# Playing 822th game | Success Rate: 66.14
# Playing 823th game | Success Rate: 66.18
# Playing 824th game | Success Rate: 66.22
# Playing 825th game | Success Rate: 66.26
# Playing 826th game | Success Rate: 66.30
# Playing 827th game | Success Rate: 66.34
# Playing 828th game | Success Rate: 66.39
# Playing 829th game | Success Rate: 66.43
# Playing 830th game | Success Rate: 66.35
# Playing 831th game | Success Rate: 66.27
# Playing 832th game | Success Rate: 66.31
# Playing 833th game | Success Rate: 66.35
# Playing 834th game | Success Rate: 66.39
# Playing 835th game | Success Rate: 66.43
# Playing 836th game | Success Rate: 66.47
# Playing 837th game | Success Rate: 66.51
# Playing 838th game | Success Rate: 66.55
# Playing 839th game | Success Rate: 66.59
# Playing 840th game | Success Rate: 66.63
# Playing 841th game | Success Rate: 66.67
# Playing 842th game | Success Rate: 66.71
# Playing 843th game | Success Rate: 66.63
# Playing 844th game | Success Rate: 66.67
# Playing 845th game | Success Rate: 66.71
# Playing 846th game | Success Rate: 66.75
# Playing 847th game | Success Rate: 66.78
# Playing 848th game | Success Rate: 66.71
# Playing 849th game | Success Rate: 66.75
# Playing 850th game | Success Rate: 66.67
# Playing 851th game | Success Rate: 66.59
# Playing 852th game | Success Rate: 66.63
# Playing 853th game | Success Rate: 66.55
# Playing 854th game | Success Rate: 66.47
# Playing 855th game | Success Rate: 66.51
# Playing 856th game | Success Rate: 66.55
# Playing 857th game | Success Rate: 66.47
# Playing 858th game | Success Rate: 66.40
# Playing 859th game | Success Rate: 66.43
# Playing 860th game | Success Rate: 66.36
# Playing 861th game | Success Rate: 66.40
# Playing 862th game | Success Rate: 66.44
# Playing 863th game | Success Rate: 66.36
# Playing 864th game | Success Rate: 66.40
# Playing 865th game | Success Rate: 66.44
# Playing 866th game | Success Rate: 66.47
# Playing 867th game | Success Rate: 66.51
# Playing 868th game | Success Rate: 66.44
# Playing 869th game | Success Rate: 66.48
# Playing 870th game | Success Rate: 66.51
# Playing 871th game | Success Rate: 66.44
# Playing 872th game | Success Rate: 66.48
# Playing 873th game | Success Rate: 66.51
# Playing 874th game | Success Rate: 66.55
# Playing 875th game | Success Rate: 66.48
# Playing 876th game | Success Rate: 66.40
# Playing 877th game | Success Rate: 66.44
# Playing 878th game | Success Rate: 66.48
# Playing 879th game | Success Rate: 66.52
# Playing 880th game | Success Rate: 66.44
# Playing 881th game | Success Rate: 66.48
# Playing 882th game | Success Rate: 66.40
# Playing 883th game | Success Rate: 66.33
# Playing 884th game | Success Rate: 66.25
# Playing 885th game | Success Rate: 66.29
# Playing 886th game | Success Rate: 66.33
# Playing 887th game | Success Rate: 66.37
# Playing 888th game | Success Rate: 66.40
# Playing 889th game | Success Rate: 66.33
# Playing 890th game | Success Rate: 66.26
# Playing 891th game | Success Rate: 66.18
# Playing 892th game | Success Rate: 66.11
# Playing 893th game | Success Rate: 66.15
# Playing 894th game | Success Rate: 66.07
# Playing 895th game | Success Rate: 66.11
# Playing 896th game | Success Rate: 66.04
# Playing 897th game | Success Rate: 65.96
# Playing 898th game | Success Rate: 66.00
# Playing 899th game | Success Rate: 66.04
# Playing 900th game | Success Rate: 65.96
# Playing 901th game | Success Rate: 65.89
# Playing 902th game | Success Rate: 65.82
# Playing 903th game | Success Rate: 65.86
# Playing 904th game | Success Rate: 65.89
# Playing 905th game | Success Rate: 65.93
# Playing 906th game | Success Rate: 65.97
# Playing 907th game | Success Rate: 66.01
# Playing 908th game | Success Rate: 65.93
# Playing 909th game | Success Rate: 65.97
# Playing 910th game | Success Rate: 65.90
# Playing 911th game | Success Rate: 65.94
# Playing 912th game | Success Rate: 65.97
# Playing 913th game | Success Rate: 65.90
# Playing 914th game | Success Rate: 65.94
# Playing 915th game | Success Rate: 65.98
# Playing 916th game | Success Rate: 65.90
# Playing 917th game | Success Rate: 65.83
# Playing 918th game | Success Rate: 65.87
# Playing 919th game | Success Rate: 65.91
# Playing 920th game | Success Rate: 65.94
# Playing 921th game | Success Rate: 65.87
# Playing 922th game | Success Rate: 65.91
# Playing 923th game | Success Rate: 65.95
# Playing 924th game | Success Rate: 65.98
# Playing 925th game | Success Rate: 66.02
# Playing 926th game | Success Rate: 65.95
# Playing 927th game | Success Rate: 65.98
# Playing 928th game | Success Rate: 66.02
# Playing 929th game | Success Rate: 66.06
# Playing 930th game | Success Rate: 66.09
# Playing 931th game | Success Rate: 66.02
# Playing 932th game | Success Rate: 66.06
# Playing 933th game | Success Rate: 66.10
# Playing 934th game | Success Rate: 66.13
# Playing 935th game | Success Rate: 66.06
# Playing 936th game | Success Rate: 66.10
# Playing 937th game | Success Rate: 66.03
# Playing 938th game | Success Rate: 65.96
# Playing 939th game | Success Rate: 65.89
# Playing 940th game | Success Rate: 65.82
# Playing 941th game | Success Rate: 65.85
# Playing 942th game | Success Rate: 65.89
# Playing 943th game | Success Rate: 65.82
# Playing 944th game | Success Rate: 65.75
# Playing 945th game | Success Rate: 65.68
# Playing 946th game | Success Rate: 65.61
# Playing 947th game | Success Rate: 65.54
# Playing 948th game | Success Rate: 65.58
# Playing 949th game | Success Rate: 65.62
# Playing 950th game | Success Rate: 65.65
# Playing 951th game | Success Rate: 65.69
# Playing 952th game | Success Rate: 65.72
# Playing 953th game | Success Rate: 65.76
# Playing 954th game | Success Rate: 65.79
# Playing 955th game | Success Rate: 65.83
# Playing 956th game | Success Rate: 65.87
# Playing 957th game | Success Rate: 65.90
# Playing 958th game | Success Rate: 65.94
# Playing 959th game | Success Rate: 65.97
# Playing 960th game | Success Rate: 66.01
# Playing 961th game | Success Rate: 66.04
# Playing 962th game | Success Rate: 66.08
# Playing 963th game | Success Rate: 66.11
# Playing 964th game | Success Rate: 66.15
# Playing 965th game | Success Rate: 66.18
# Playing 966th game | Success Rate: 66.22
# Playing 967th game | Success Rate: 66.25
# Playing 968th game | Success Rate: 66.29
# Playing 969th game | Success Rate: 66.22
# Playing 970th game | Success Rate: 66.26
# Playing 971th game | Success Rate: 66.29
# Playing 972th game | Success Rate: 66.22
# Playing 973th game | Success Rate: 66.26
# Playing 974th game | Success Rate: 66.19
# Playing 975th game | Success Rate: 66.22
# Playing 976th game | Success Rate: 66.26
# Playing 977th game | Success Rate: 66.29
# Playing 978th game | Success Rate: 66.33
# Playing 979th game | Success Rate: 66.36
# Playing 980th game | Success Rate: 66.29
# Playing 981th game | Success Rate: 66.33
# Playing 982th game | Success Rate: 66.36
# Playing 983th game | Success Rate: 66.40
# Playing 984th game | Success Rate: 66.43
# Playing 985th game | Success Rate: 66.46
# Playing 986th game | Success Rate: 66.40
# Playing 987th game | Success Rate: 66.43
# Playing 988th game | Success Rate: 66.36
# Playing 989th game | Success Rate: 66.40
# Playing 990th game | Success Rate: 66.43
# Playing 991th game | Success Rate: 66.36
# Playing 992th game | Success Rate: 66.40
# Playing 993th game | Success Rate: 66.43
# Playing 994th game | Success Rate: 66.47
# Playing 995th game | Success Rate: 66.50
# Playing 996th game | Success Rate: 66.43
# Playing 997th game | Success Rate: 66.47
# ---------------------------------------------------------------------------
# HangmanAPIError                           Traceback (most recent call last)
# Cell In[13], line 2
#       1 for i in range(594,1000):
# ----> 2     api.start_game(practice=0,verbose=False)
#       3     # api.start_game(practice=1,verbose=True)
#       4     [total_practice_runs,total_recorded_runs,total_recorded_successes,total_practice_successes] = api.my_status() # Get my game stats: (# of tries, # of wins)
#
# Cell In[9], line 52, in HangmanAPI.start_game(self, practice, verbose)
#      49 self.guessed_letters = []
#      50 self.current_dictionary = self.full_dictionary
# ---> 52 response = self.request("/new_game", {"practice":practice})
#      53 if response.get('status')=="approved":
#      54     game_id = response.get('game_id')
#
# Cell In[9], line 154, in HangmanAPI.request(self, path, args, post_args, method)
#     151     raise HangmanAPIError('Maintype was not text, or querystring')
#     153 if result and isinstance(result, dict) and result.get("error"):
# --> 154     raise HangmanAPIError(result)
#     155 return result
#
# HangmanAPIError: {'error': 'You have reached 1000 of games', 'status': 'denied'}

# %%
for i in range(1000):
    print('Playing ', i, ' th game')
    #Uncomment the following line to execute your final runs. Do not do this until you are satisfied with your submission
    api.start_game(practice=0,verbose=False)
    
    #DO NOT REMOVE as otherwise the server may lock you out for too high frequency of requests
    time.sleep(0.5)

# %% [markdown]
# ## To check your game statistics
# 1. Simply use "my_status" method.
# 2. Returns your total number of games, and number of wins.

# %%
[total_practice_runs,total_recorded_runs,total_recorded_successes,total_practice_successes] = api.my_status() # Get my game stats: (# of tries, # of wins)
success_rate = total_recorded_successes/total_recorded_runs
print('overall success rate = %.4f' % success_rate)
# Out:
# overall success rate = 0.6640
